# %% [markdown]
# <a href="https://colab.research.google.com/github/brunocalicchia-hash/nlp00/blob/master/Copia_di_Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install PyPDF2

# %%
import PyPDF2
article_file = open('articolo_ai.pdf', 'ab+')
article_pdf = PyPDF2.PdfFileReader(article_file)
type(article_pdf) PyPDF2.pdf.PdfFileReader
article_pdf.getis_encrypted() False
article_pdf.numpages 7
page_one = article_pdf.getPages(0)
type(page_one) PyPDF2.pdf.PageObject
page_one_text = page_one.extractText()
print(page_one_text)
# Out:
#   File "/tmp/ipython-input-1537426519.py", line 4
#     type(article_pdf) PyPDF2.pdf.PdfFileReader
#                       ^
# SyntaxError: invalid syntax
